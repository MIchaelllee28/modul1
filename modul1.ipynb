# %% [markdown]
# <a href="https://colab.research.google.com/github/MIchaelllee28/modul1/blob/main/modul1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# LANGKAH 1
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow #for image display
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %%
# LANGKAH 2
# Membuat list untuk menyimpan url dari beberapa image
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
        "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
        "https://placekitten.com/800/571",
        "https://i.postimg.cc/Qx8z2t7X/e28be169-21e0-406e-bd5f-1f8b553a73f0.jpg"]

urlz = ["https://i.postimg.cc/Qx8z2t7X/e28be169-21e0-406e-bd5f-1f8b553a73f0.jpg"]
# baca dan tampilkan image
# loop pada tiap url image, beberapa image dapat disimpan pada list
for url in urls:
  image = io.imread(url)                          #read image
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5) #resize image to half size
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)  #convert color to RGB
  final_frame = cv.hconcat((image, image_2))     #concatenate image
  cv2_imshow(final_frame)                         #show image
  print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276 at 0x7FCA059EDFA0>
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7FCA059EDD90>
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7FCA059EDFA0>
# <PIL.Image.Image image mode=RGB size=458x400 at 0x7FCA0E5FF700>

# %%
# LANGKAH 3
# Melihat ukuran file image
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("resolusi image: tinggi x lebar = ",tinggi," x ",lebar)
cv2_imshow(image_2)
# Out:
# resolusi image: tinggi x lebar =  400  x  229
# <PIL.Image.Image image mode=RGB size=229x400 at 0x7FCA0D6CFD90>

# %%
# LANGKAH 4
# Mengakses pixel dengan memberi garis diagonal menyilang
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# membuat garis horizontal di tengah image
for y in range (lebar):
  image_3[int((tinggi)/2),y] = [255,255,0]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=458x400 at 0x7FCA059EDFD0>

# %% [markdown]
# PERTANYAAN
#
# 1. Jelaskan, mengapa pada modul praktikum ini eksekusi kode Python dilakukan menggunakan Google Colab?
#
#   Pada google collab , sudah ada banyak library python yang langsung terhubung dengan cloud, jadi kita tidak perlu lagi untuk mendownload
#   satu persatu setiap library yang akan digunakan, selain itu google collab juga memungkinkan proses run secara langsung, jadi bisa langsung kita cek
#   apakah kode python berjalan atau tidak
#
# 2. Jelaskan mengenai kegunaan setiap library pada praktikum langkah ke delapan? Apakah semua library tersebut harus digunakan dalam praktikum sesi ini?
#
#   Numpy : digunakan untuk data sains seperti menghitung operasi matematika dan array
#   Pandas : digunakan untuk menganalisis data serta membangun sebuah machine learning.
#   CV2 : digunakan untuk memanggil modul opencv untuk proses input,simpan dan menampilkan citra/image
#   Skimage : digunakan untuk pemrosesan gambar dan visi komputer.
#   PIL : digunakan untuk melakukan operasi dasar pada gambar seperti mengubah ukuran, rotasi, membuat thumbnail, mengkonversi antara format file yang berbeda, dll.
#   Matplotlib : digunakan untuk menampilkan visualisasi grafik/gambar dalam kualitas yang bagus
#
# 3. Pada uji coba langkah ke-9 terdapat potongan kode program sebagai berikut, Apa kegunaan kode program tersebut? dan apa pengaruhnya jika tidak dilakukan?
#   Kode program tersebut digunakan untuk meresize ukuran gambar menjadi setengah ukuran aslinya,
#   Jika tidak dilakukan ukuran gambar akan menjadi dua kali lipat lebih besar
#
# 4. Perhatikan potongan kode program berikut: image.png Apakah kegunaan kode [255,255,255] ? Jelaskan!
#
#   Kode tersebut digunakan untuk mengatur warna agar bisa menjadi warna putih pada garis horizontal yang dibuat pada gambar, baris angka mewakili red, green, blue.
#
# 5. Jelaskan keterkaitan antara pixel dan juga resolusi gambar yang tinggi ataupun rendah!
#
#   Pixel adalah elemen gambar terkecil dari citra digital.Resolusi merupakan jumlah pixel atau kerapatan pixel yang tersusun dalam suatu gambar digital. Maka semakin tinggi resolusi yag suatu gambar miliki, semakin jernih juga kualitasnya.

# %%
# TUGAS
# GARIS VERTIKAL dan DIAGONAL
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# membuat garis vertikal di tengah image
for x in range (tinggi):
  image_3[x, int((lebar)/2)] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)

# membuat garis diagonal
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

line1_1 = (0,0)
line1_2 = (400,700)

line2_1 = (220,0)
line2_2 = (0,400)

cv.line(image_3, line1_1, line1_2, (255,255,255))
cv.line(image_3, line2_1, line2_2, (255,255,255))

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=458x400 at 0x7FCA059FE310>
# <PIL.Image.Image image mode=RGB size=458x400 at 0x7FCA059FE820>

# %%
# membuat garis diagonal tanpa cv.line
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for y in range (tinggi):
  image_3[y,int(y*(lebar/tinggi))] = [255,255,255]
  image_3[y,lebar-1-int(y*(lebar/tinggi))] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=458x400 at 0x7FCA0C6762E0>
